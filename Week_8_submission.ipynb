# %%
import pandas as pd
games = pd.read_csv("/Users/yangzhengyang/Desktop/uw/msti/course/TECHIN_509_Technology_Foundations/Week_8/Week_8_games.csv")
games
# Out:
#    Game ID Player X Player O   Winner
# 0        1  Ronaldo    Messi  Ronaldo
# 1        2  Ronaldo   Neymar  Ronaldo
# 2        3  Ronaldo  Beckham  Beckham
# 3        4  Ronaldo   Cavani   Cavani
# 4        5  Ronaldo   Catona  Ronaldo
# 5        6  Ronaldo     Bale  Ronaldo
# 6        7  Ronaldo   Modric  Ronaldo

# %%
number_of_games = len(games['Game ID'].unique())
number_of_games
# Out:
# 7

# %%
winner = [games["Winner"] == "Ronaldo"]
winner
# Out:
# [0     True
#  1     True
#  2    False
#  3    False
#  4     True
#  5     True
#  6     True
#  Name: Winner, dtype: bool]

# %%
games.groupby('Winner').Winner.count().plot.pie()
# Out:
# <AxesSubplot:ylabel='Winner'>

# %%
games['Player O'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Player O'>

# %%
result = games['Winner'].value_counts()
result
# Out:
# Ronaldo    5
# Beckham    1
# Cavani     1
# Name: Winner, dtype: int64

# %%
games['Player X'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Player X'>
